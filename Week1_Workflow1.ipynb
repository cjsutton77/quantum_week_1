# %% [markdown]
# ## Quantun LiveProject: *Week 1*

# %% [markdown]
# ## Workflow 1: Real, Imaginary and Complex Numbers

# %% [markdown]
# ### Reviewer: Christian Sutton ---  christian.sutton@gmail.com

# %%
import math
import cmath
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Deliverables

# %% [markdown]
# #### Question 1:  For the given list of complex numbers can you add them all together?
#
# #### Question 2:  Can you do the above using list comprehensions?
#
# #### Question 3:  Can you also plot these numbers using a cartesian plot?

# %%
complex_numbers = [
    complex(1,1), 
    complex(2,1), 
    complex(6,3), 
    complex(-3,4), 
    complex(6,-1)
]

# %%
[sum(complex_numbers[0:i+1]) for i,j in enumerate(complex_numbers)][-1]
# Out:
# (12+8j)

# %%
sum(complex_numbers)
# Out:
# (12+8j)

# %%
for x in complex_numbers:
    r, phi = cmath.polar(x)
    plt.polar([0,phi],[0,r], marker='o')
